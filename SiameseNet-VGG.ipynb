# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/keras-oneshot
# !ls
# Out:
# /content/drive/MyDrive/keras-oneshot
# images	      omniglot		SiameseNet.ipynb      util.py	    weights
# LICENSE       README.md		SiameseNet-VGG.ipynb  val.pickle
# load_data.py  requirements.txt	train.pickle	      vis_utils.py

# %%
from keras.layers import Input, Conv2D, Lambda, merge, Dense, Flatten,MaxPooling2D, GlobalAveragePooling2D, Dropout, Concatenate
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
from keras.applications import VGG16
import numpy.random as rng
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
# %matplotlib inline
# def W_init(shape,dtype=None):
#     """Initialize weights as in paper"""
#     return rng.normal(loc = 0.0, scale = 1e-2, size = shape)
# #//TODO: figure out how to initialize layer biases in keras.
# def b_init(shape,dtype=None):
#     """Initialize bias as in paper"""
#     return rng.normal(loc=0.5,scale=1e-2,size=shape)

input_shape = (105, 105, 1)
img_input = Input(shape = input_shape)
img_conc = Concatenate()([img_input, img_input, img_input])
left_input = Input(input_shape)
right_input = Input(input_shape)

#build convnet to use in each siamese 'leg'
vgg = VGG16(weights = 'imagenet', include_top = False, input_tensor = img_conc)

for layer in vgg.layers:
  layer.trainable = False

convnet = Sequential()
# convnet.add(Conv2D(64,(10,10),activation='relu',input_shape=input_shape,
#                    kernel_initializer=W_init,kernel_regularizer=l2(2e-4)))
# convnet.add(MaxPooling2D())
# convnet.add(Conv2D(128,(7,7),activation='relu',
#                    kernel_regularizer=l2(2e-4),kernel_initializer=W_init,bias_initializer=b_init))
# convnet.add(MaxPooling2D())
# convnet.add(Conv2D(128,(4,4),activation='relu',kernel_initializer=W_init,kernel_regularizer=l2(2e-4),bias_initializer=b_init))
# convnet.add(MaxPooling2D())
# convnet.add(Conv2D(256,(4,4),activation='relu',kernel_initializer=W_init,kernel_regularizer=l2(2e-4),bias_initializer=b_init))
# convnet.add(Flatten())
# convnet.add(Dense(4096,activation="sigmoid",kernel_regularizer=l2(1e-3),kernel_initializer=W_init,bias_initializer=b_init))

convnet.add(vgg)
convnet.add(GlobalAveragePooling2D())
convnet.add(Dropout(0.3))
convnet.add(Dense(4096, activation = 'sigmoid'))

#call the convnet Sequential model on each of the input tensors so params will be shared
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)
#layer to merge two encoded inputs with the l1 distance between them
L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
#call this layer on list of two input tensors.
L1_distance = L1_layer([encoded_l, encoded_r])
prediction = Dense(1,activation='sigmoid')(L1_distance)
siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
siamese_net.summary()

optimizer = Adam(0.00006)
#//TODO: get layerwise learning rates and momentum annealing scheme described in paperworking
siamese_net.compile(loss="binary_crossentropy",optimizer=optimizer)

#siamese_net.count_params()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 105, 105, 1) 0
# __________________________________________________________________________________________________
# input_9 (InputLayer)            [(None, 105, 105, 1) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 4096)         16815936    input_8[0][0]
#                                                                  input_9[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 4096)         0           sequential[0][0]
#                                                                  sequential[1][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            4097        lambda[0][0]
# ==================================================================================================
# Total params: 16,820,033
# Trainable params: 2,105,345
# Non-trainable params: 14,714,688
# __________________________________________________________________________________________________

# %% [markdown]
# ## Data
# The data is pickled as an N_classes x n_examples x width x height array, and there is an accompanyng dictionary to specify which indexes belong to which languages.

# %%
PATH = "/content/drive/MyDrive/keras-oneshot" 

with open(os.path.join(PATH, "train.pickle"), "rb") as f:
    (X,c) = pickle.load(f)

with open(os.path.join(PATH, "val.pickle"), "rb") as f:
    (Xval,cval) = pickle.load(f)
    
print("training alphabets")
print(c.keys())
print("validation alphabets:")
print(cval.keys())
# Out:
# training alphabets
# dict_keys(['Alphabet_of_the_Magi', 'Bengali', 'Gujarati', 'Japanese_(katakana)', 'Mkhedruli_(Georgian)', 'Tagalog', 'Hebrew', 'Burmese_(Myanmar)', 'Early_Aramaic', 'Grantha', 'Armenian', 'Futurama', 'Tifinagh', 'Greek', 'Syriac_(Estrangelo)', 'Arcadian', 'Anglo-Saxon_Futhorc', 'Asomtavruli_(Georgian)', 'Malay_(Jawi_-_Arabic)', 'N_Ko', 'Sanskrit', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Braille', 'Korean', 'Cyrillic', 'Latin', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Balinese', 'Japanese_(hiragana)'])
# validation alphabets:
# dict_keys(['Aurek-Besh', 'Tengwar', 'Tibetan', 'Malayalam', 'Ge_ez', 'Glagolitic', 'Atlantean', 'Keble', 'Manipuri', 'Avesta', 'Mongolian', 'Old_Church_Slavonic_(Cyrillic)', 'Kannada', 'Atemayar_Qelisayer', 'Sylheti', 'ULOG', 'Syriac_(Serto)', 'Gurmukhi', 'Oriya', 'Angelic'])

# %%
class Siamese_Loader:
    """For loading batches and testing tasks to a siamese net"""
    def __init__(self, path, data_subsets = ["train", "val"]):
        self.data = {}
        self.categories = {}
        self.info = {}
        
        for name in data_subsets:
            file_path = os.path.join(path, name + ".pickle")
            print("loading data from {}".format(file_path))
            with open(file_path,"rb") as f:
                (X,c) = pickle.load(f)
                self.data[name] = X
                self.categories[name] = c

    def get_batch(self,batch_size,s="train"):
        """Create batch of n pairs, half same class, half different class"""
        X=self.data[s]
        n_classes, n_examples, w, h = X.shape

        #randomly sample several classes to use in the batch
        categories = rng.choice(n_classes,size=(batch_size,),replace=False)
        #initialize 2 empty arrays for the input image batch
        pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
        #initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
        targets=np.zeros((batch_size,))
        targets[batch_size//2:] = 1
        for i in range(batch_size):
            category = categories[i]
            idx_1 = rng.randint(0, n_examples)
            pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
            idx_2 = rng.randint(0, n_examples)
            #pick images of same class for 1st half, different for 2nd
            if i >= batch_size // 2:
                category_2 = category  
            else: 
                #add a random number to the category modulo n classes to ensure 2nd image has
                # ..different category
                category_2 = (category + rng.randint(1,n_classes)) % n_classes
            pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
        return pairs, targets
    
    def generate(self, batch_size, s="train"):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.get_batch(batch_size,s)
            yield (pairs, targets)    

    def make_oneshot_task(self,N,s="val",language=None):
        """Create pairs of test image, support set for testing N way one-shot learning. """
        X=self.data[s]
        n_classes, n_examples, w, h = X.shape
        indices = rng.randint(0,n_examples,size=(N,))
        if language is not None:
            low, high = self.categories[s][language]
            if N > high - low:
                raise ValueError("This language ({}) has less than {} letters".format(language, N))
            categories = rng.choice(range(low,high),size=(N,),replace=False)
            
        else:#if no language specified just pick a bunch of random letters
            categories = rng.choice(range(n_classes),size=(N,),replace=False)            
        true_category = categories[0]
        ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
        test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
        support_set = X[categories,indices,:,:]
        support_set[0,:,:] = X[true_category,ex2]
        support_set = support_set.reshape(N, w, h,1)
        targets = np.zeros((N,))
        targets[0] = 1
        targets, test_image, support_set = shuffle(targets, test_image, support_set)
        pairs = [test_image,support_set]

        return pairs, targets
    
    def test_oneshot(self,model,N,k,s="val",verbose=0):
        """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
        n_correct = 0
        if verbose:
            print("Evaluating model on {} random {} way one-shot learning tasks ...".format(k,N))
        for i in range(k):
            inputs, targets = self.make_oneshot_task(N,s)
            probs = model.predict(inputs)
            if np.argmax(probs) == np.argmax(targets):
                n_correct+=1
        percent_correct = (100.0*n_correct / k)
        if verbose:
            print("Got an average of {}% {} way one-shot learning accuracy".format(percent_correct,N))
        return percent_correct
    
    def train(self, model, epochs, verbosity):
        model.fit_generator(self.generate(batch_size))
    
#Instantiate the class
loader = Siamese_Loader(PATH)
# Out:
# loading data from /content/drive/MyDrive/keras-oneshot/train.pickle
# loading data from /content/drive/MyDrive/keras-oneshot/val.pickle

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc,h,w,_ = X.shape
    X = X.reshape(nc,h,w)
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img


def plot_oneshot_task(pairs):
    """Takes a one-shot task given to a siamese net and  """
    fig,(ax1,ax2) = plt.subplots(2)
    ax1.matshow(pairs[0][0].reshape(105,105),cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()
#example of a one-shot learning task
pairs, targets = loader.make_oneshot_task(20,"train","Japanese_(katakana)")
plot_oneshot_task(pairs)

# %%
#Training loop
print("!")
evaluate_every = 1 # interval for evaluating on one-shot tasks
loss_every=50 # interval for printing loss (iterations)
batch_size = 32
n_iter = 300
N_way = 20 # how many classes for testing one-shot tasks>
n_val = 250 #how mahy one-shot tasks to validate on?
best = -1
weights_path = os.path.join(PATH, "weights")
print("training")
for i in range(1, n_iter):
    print("Epochs",i,"\n")
    (inputs,targets)=loader.get_batch(batch_size)
    loss=siamese_net.train_on_batch(inputs,targets)
    print(loss)
    if i % evaluate_every == 0:
        print("evaluating")
        val_acc = loader.test_oneshot(siamese_net,N_way,n_val,verbose=True)
        if val_acc >= best:
            print("saving")
            siamese_net.save(weights_path)
            best=val_acc

    if i % loss_every == 0:
        print("iteration {}, training loss: {:.2f},".format(i,loss))
# Out:
# !
# training
# Epochs 1
#
# 0.7738722562789917
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 3.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 2
#
# 0.7036464214324951
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 2.4% 20 way one-shot learning accuracy
# Epochs 3
#
# 0.7120768427848816
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 2.0% 20 way one-shot learning accuracy
# Epochs 4
#
# 0.6484660506248474
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 4.0% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 5
#
# 0.7104848623275757
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 6.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 6
#
# 0.6976032853126526
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 7.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 7
#
# 0.7324835658073425
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 6.0% 20 way one-shot learning accuracy
# Epochs 8
#
# 0.7375731468200684
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 8.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 9
#
# 0.5893371105194092
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 8.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 10
#
# 0.6682966351509094
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 11
#
# 0.6416794657707214
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 11.6% 20 way one-shot learning accuracy
# Epochs 12
#
# 0.6400113105773926
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 7.2% 20 way one-shot learning accuracy
# Epochs 13
#
# 0.5961239337921143
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 13.6% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 14
#
# 0.7066529393196106
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 15
#
# 0.657688558101654
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.0% 20 way one-shot learning accuracy
# Epochs 16
#
# 0.6814544796943665
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 17
#
# 0.6785869598388672
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.8% 20 way one-shot learning accuracy
# Epochs 18
#
# 0.7281529903411865
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 13.2% 20 way one-shot learning accuracy
# Epochs 19
#
# 0.6418997049331665
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.8% 20 way one-shot learning accuracy
# Epochs 20
#
# 0.6455909013748169
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.4% 20 way one-shot learning accuracy
# Epochs 21
#
# 0.7025386095046997
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 10.8% 20 way one-shot learning accuracy
# Epochs 22
#
# 0.63894122838974
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 9.6% 20 way one-shot learning accuracy
# Epochs 23
#
# 0.6556218862533569
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.8% 20 way one-shot learning accuracy
# Epochs 24
#
# 0.6891428232192993
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.0% 20 way one-shot learning accuracy
# Epochs 25
#
# 0.7684493064880371
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 9.6% 20 way one-shot learning accuracy
# Epochs 26
#
# 0.6492958664894104
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 8.4% 20 way one-shot learning accuracy
# Epochs 27
#
# 0.6639243364334106
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 9.6% 20 way one-shot learning accuracy
# Epochs 28
#
# 0.7634258270263672
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 9.2% 20 way one-shot learning accuracy
# Epochs 29
#
# 0.5895856022834778
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 7.6% 20 way one-shot learning accuracy
# Epochs 30
#
# 0.6780062913894653
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 10.4% 20 way one-shot learning accuracy
# Epochs 31
#
# 0.6497581005096436
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 10.8% 20 way one-shot learning accuracy
# Epochs 32
#
# 0.6566887497901917
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.0% 20 way one-shot learning accuracy
# Epochs 33
#
# 0.6794706583023071
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 10.8% 20 way one-shot learning accuracy
# Epochs 34
#
# 0.7122630476951599
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.4% 20 way one-shot learning accuracy
# Epochs 35
#
# 0.622531533241272
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 13.6% 20 way one-shot learning accuracy
# Epochs 36
#
# 0.6121149063110352
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 11.6% 20 way one-shot learning accuracy
# Epochs 37
#
# 0.6347670555114746
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 13.6% 20 way one-shot learning accuracy
# Epochs 38
#
# 0.6673349738121033
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.8% 20 way one-shot learning accuracy
# Epochs 39
#
# 0.6854532957077026
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 10.4% 20 way one-shot learning accuracy
# Epochs 40
#
# 0.6143133640289307
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# Epochs 41
#
# 0.6120399236679077
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.4% 20 way one-shot learning accuracy
# Epochs 42
#
# 0.6064709424972534
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.8% 20 way one-shot learning accuracy
# Epochs 43
#
# 0.660217821598053
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 44
#
# 0.6748483180999756
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 10.8% 20 way one-shot learning accuracy
# Epochs 45
#
# 0.6117761135101318
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.4% 20 way one-shot learning accuracy
# Epochs 46
#
# 0.6676387786865234
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.8% 20 way one-shot learning accuracy
# Epochs 47
#
# 0.6147217750549316
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.4% 20 way one-shot learning accuracy
# Epochs 48
#
# 0.6496301293373108
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 49
#
# 0.6761332750320435
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 50
#
# 0.6856933236122131
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.4% 20 way one-shot learning accuracy
# iteration 50, training loss: 0.69,
# Epochs 51
#
# 0.614057183265686
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 52
#
# 0.6900996565818787
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.8% 20 way one-shot learning accuracy
# Epochs 53
#
# 0.7016885280609131
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 13.2% 20 way one-shot learning accuracy
# Epochs 54
#
# 0.6114751100540161
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 55
#
# 0.599686324596405
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 56
#
# 0.6358538269996643
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.4% 20 way one-shot learning accuracy
# Epochs 57
#
# 0.6492670178413391
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.0% 20 way one-shot learning accuracy
# Epochs 58
#
# 0.575738251209259
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 59
#
# 0.649675726890564
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.8% 20 way one-shot learning accuracy
# Epochs 60
#
# 0.5323448181152344
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.0% 20 way one-shot learning accuracy
# Epochs 61
#
# 0.6925902366638184
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.4% 20 way one-shot learning accuracy
# Epochs 62
#
# 0.6341934204101562
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.4% 20 way one-shot learning accuracy
# Epochs 63
#
# 0.602442741394043
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 13.2% 20 way one-shot learning accuracy
# Epochs 64
#
# 0.6771532297134399
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 65
#
# 0.5578303933143616
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.4% 20 way one-shot learning accuracy
# Epochs 66
#
# 0.5488932132720947
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 67
#
# 0.6760435104370117
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.4% 20 way one-shot learning accuracy
# Epochs 68
#
# 0.7212750315666199
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 69
#
# 0.6188613772392273
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# Epochs 70
#
# 0.550865113735199
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 71
#
# 0.5936399698257446
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 72
#
# 0.5417234897613525
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 73
#
# 0.674659252166748
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 74
#
# 0.5299580097198486
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.4% 20 way one-shot learning accuracy
# Epochs 75
#
# 0.58487868309021
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.4% 20 way one-shot learning accuracy
# Epochs 76
#
# 0.7059680223464966
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 77
#
# 0.5247012376785278
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# Epochs 78
#
# 0.5798521041870117
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 79
#
# 0.5344207286834717
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 80
#
# 0.5570290088653564
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# Epochs 81
#
# 0.5364333391189575
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.4% 20 way one-shot learning accuracy
# Epochs 82
#
# 0.633338451385498
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# Epochs 83
#
# 0.5847558379173279
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.0% 20 way one-shot learning accuracy
# Epochs 84
#
# 0.47846731543540955
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 11.6% 20 way one-shot learning accuracy
# Epochs 85
#
# 0.5556607246398926
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# Epochs 86
#
# 0.5666528344154358
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# Epochs 87
#
# 0.5826627016067505
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.8% 20 way one-shot learning accuracy
# Epochs 88
#
# 0.6139471530914307
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 89
#
# 0.5907766819000244
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.4% 20 way one-shot learning accuracy
# Epochs 90
#
# 0.6178456544876099
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.4% 20 way one-shot learning accuracy
# Epochs 91
#
# 0.5784653425216675
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 92
#
# 0.5639628171920776
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 93
#
# 0.6224284172058105
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 94
#
# 0.6886011362075806
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# Epochs 95
#
# 0.6312161087989807
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# Epochs 96
#
# 0.5450055003166199
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 97
#
# 0.5967177152633667
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 13.6% 20 way one-shot learning accuracy
# Epochs 98
#
# 0.4700459837913513
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# Epochs 99
#
# 0.5618511438369751
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.4% 20 way one-shot learning accuracy
# Epochs 100
#
# 0.5250786542892456
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# iteration 100, training loss: 0.53,
# Epochs 101
#
# 0.6868274807929993
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 10.4% 20 way one-shot learning accuracy
# Epochs 102
#
# 0.6082538366317749
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.2% 20 way one-shot learning accuracy
# Epochs 103
#
# 0.5945361852645874
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.4% 20 way one-shot learning accuracy
# Epochs 104
#
# 0.4766528606414795
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# Epochs 105
#
# 0.5195468664169312
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 106
#
# 0.5253574848175049
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 107
#
# 0.6380683779716492
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.2% 20 way one-shot learning accuracy
# Epochs 108
#
# 0.6384979486465454
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# Epochs 109
#
# 0.5946950316429138
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# Epochs 110
#
# 0.49755728244781494
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 111
#
# 0.5434660315513611
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# Epochs 112
#
# 0.4865630269050598
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.8% 20 way one-shot learning accuracy
# Epochs 113
#
# 0.5355624556541443
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 114
#
# 0.575908899307251
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# Epochs 115
#
# 0.4655805826187134
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# Epochs 116
#
# 0.5955477952957153
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 117
#
# 0.5188165903091431
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 118
#
# 0.6538107395172119
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# Epochs 119
#
# 0.607164204120636
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# Epochs 120
#
# 0.5842568874359131
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# Epochs 121
#
# 0.5860434174537659
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# Epochs 122
#
# 0.601193368434906
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# Epochs 123
#
# 0.5484689474105835
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# Epochs 124
#
# 0.5429157018661499
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# Epochs 125
#
# 0.5404736399650574
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# Epochs 126
#
# 0.6087371706962585
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# Epochs 127
#
# 0.4977242946624756
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 128
#
# 0.48013246059417725
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# Epochs 129
#
# 0.5726151466369629
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 12.8% 20 way one-shot learning accuracy
# Epochs 130
#
# 0.5901768207550049
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.0% 20 way one-shot learning accuracy
# Epochs 131
#
# 0.5756736993789673
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.4% 20 way one-shot learning accuracy
# Epochs 132
#
# 0.6392664313316345
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# Epochs 133
#
# 0.5821633338928223
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 134
#
# 0.5715731382369995
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 135
#
# 0.5543116927146912
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# Epochs 136
#
# 0.5598541498184204
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 137
#
# 0.5978624820709229
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# Epochs 138
#
# 0.6973649263381958
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# Epochs 139
#
# 0.533741295337677
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# Epochs 140
#
# 0.6072717905044556
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# Epochs 141
#
# 0.5510780811309814
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.4% 20 way one-shot learning accuracy
# Epochs 142
#
# 0.5148220062255859
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 143
#
# 0.5552165508270264
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 144
#
# 0.5400949716567993
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 145
#
# 0.550378143787384
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 146
#
# 0.5934034585952759
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 147
#
# 0.4914967715740204
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# Epochs 148
#
# 0.6988293528556824
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 149
#
# 0.5019693374633789
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# Epochs 150
#
# 0.5406997203826904
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.4% 20 way one-shot learning accuracy
# iteration 150, training loss: 0.54,
# Epochs 151
#
# 0.5990338325500488
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 152
#
# 0.5221054553985596
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# Epochs 153
#
# 0.5014011263847351
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 154
#
# 0.516476035118103
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.2% 20 way one-shot learning accuracy
# Epochs 155
#
# 0.5087254047393799
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# Epochs 156
#
# 0.5378425121307373
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 157
#
# 0.5649356245994568
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 158
#
# 0.5640671253204346
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 159
#
# 0.5328047275543213
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# Epochs 160
#
# 0.49166226387023926
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# Epochs 161
#
# 0.5772623419761658
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# Epochs 162
#
# 0.5713755488395691
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# Epochs 163
#
# 0.5174100995063782
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 164
#
# 0.5764338374137878
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# Epochs 165
#
# 0.5011571049690247
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 166
#
# 0.5887690782546997
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.2% 20 way one-shot learning accuracy
# Epochs 167
#
# 0.5426120162010193
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# Epochs 168
#
# 0.5994085073471069
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.4% 20 way one-shot learning accuracy
# Epochs 169
#
# 0.41891932487487793
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# Epochs 170
#
# 0.6699380874633789
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 171
#
# 0.5809685587882996
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# Epochs 172
#
# 0.620678186416626
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# Epochs 173
#
# 0.6025619506835938
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 174
#
# 0.5456962585449219
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 175
#
# 0.5097160935401917
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# Epochs 176
#
# 0.5476425886154175
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# Epochs 177
#
# 0.5174829959869385
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 178
#
# 0.5267015099525452
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.2% 20 way one-shot learning accuracy
# Epochs 179
#
# 0.6151316165924072
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# Epochs 180
#
# 0.5978648662567139
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# Epochs 181
#
# 0.4853745996952057
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 182
#
# 0.48990827798843384
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 183
#
# 0.5457664132118225
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 184
#
# 0.6355542540550232
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 185
#
# 0.5337413549423218
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 186
#
# 0.5636931657791138
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 187
#
# 0.5668165683746338
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# Epochs 188
#
# 0.5286734104156494
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 189
#
# 0.44430720806121826
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# Epochs 190
#
# 0.5807167291641235
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# Epochs 191
#
# 0.6106740236282349
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 192
#
# 0.5452136397361755
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# Epochs 193
#
# 0.5466228127479553
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# Epochs 194
#
# 0.4403403699398041
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# Epochs 195
#
# 0.5099475979804993
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# Epochs 196
#
# 0.44654542207717896
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# Epochs 197
#
# 0.5034295916557312
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# Epochs 198
#
# 0.5426157712936401
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# Epochs 199
#
# 0.5729690790176392
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 200
#
# 0.648259162902832
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# iteration 200, training loss: 0.65,
# Epochs 201
#
# 0.5730994939804077
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 202
#
# 0.5924911499023438
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# Epochs 203
#
# 0.5557616353034973
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 204
#
# 0.5307527780532837
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 205
#
# 0.5171477198600769
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# Epochs 206
#
# 0.5969789624214172
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 207
#
# 0.5617976784706116
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# Epochs 208
#
# 0.4603435695171356
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# Epochs 209
#
# 0.5552171468734741
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 210
#
# 0.49212977290153503
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 211
#
# 0.5577507019042969
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 212
#
# 0.6281554102897644
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 213
#
# 0.5585358142852783
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 214
#
# 0.5844112038612366
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# Epochs 215
#
# 0.46091967821121216
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 216
#
# 0.5566427111625671
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 217
#
# 0.4771272540092468
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# Epochs 218
#
# 0.4849392771720886
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 219
#
# 0.4986473023891449
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# Epochs 220
#
# 0.48776260018348694
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# Epochs 221
#
# 0.5156762003898621
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 222
#
# 0.5343819856643677
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 223
#
# 0.5001145005226135
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.6% 20 way one-shot learning accuracy
# Epochs 224
#
# 0.5488060712814331
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# Epochs 225
#
# 0.548616886138916
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 226
#
# 0.37206533551216125
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 227
#
# 0.5008114576339722
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 228
#
# 0.5481419563293457
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 229
#
# 0.48398450016975403
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# Epochs 230
#
# 0.5121493339538574
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 231
#
# 0.5235524773597717
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# Epochs 232
#
# 0.5567399263381958
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# Epochs 233
#
# 0.4484157860279083
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 234
#
# 0.46065860986709595
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# Epochs 235
#
# 0.5305216908454895
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# Epochs 236
#
# 0.5242441296577454
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 237
#
# 0.4646940529346466
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# Epochs 238
#
# 0.43525001406669617
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 239
#
# 0.48825448751449585
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 240
#
# 0.5015472173690796
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 241
#
# 0.4460931420326233
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 242
#
# 0.4389684200286865
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 243
#
# 0.5771921873092651
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# Epochs 244
#
# 0.4661655128002167
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# Epochs 245
#
# 0.39708608388900757
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# Epochs 246
#
# 0.5689590573310852
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# Epochs 247
#
# 0.5178039073944092
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# Epochs 248
#
# 0.4449369013309479
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# Epochs 249
#
# 0.4103124141693115
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# Epochs 250
#
# 0.5057840347290039
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# iteration 250, training loss: 0.51,
# Epochs 251
#
# 0.4084162712097168
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 252
#
# 0.4694526791572571
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 253
#
# 0.4958731234073639
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# Epochs 254
#
# 0.5502359867095947
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# Epochs 255
#
# 0.5439777374267578
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 256
#
# 0.4876367449760437
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.6% 20 way one-shot learning accuracy
# Epochs 257
#
# 0.6468746066093445
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 258
#
# 0.5222084522247314
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 259
#
# 0.41410666704177856
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# Epochs 260
#
# 0.4128461480140686
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# Epochs 261
#
# 0.549534797668457
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 262
#
# 0.568780779838562
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 263
#
# 0.4243200123310089
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.0% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 264
#
# 0.6121958494186401
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# Epochs 265
#
# 0.5802068114280701
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 266
#
# 0.5526720285415649
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 267
#
# 0.532580554485321
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# Epochs 268
#
# 0.6486956477165222
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 269
#
# 0.5436398983001709
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.4% 20 way one-shot learning accuracy
# Epochs 270
#
# 0.5722321271896362
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# Epochs 271
#
# 0.5979450941085815
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# Epochs 272
#
# 0.4573672115802765
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# Epochs 273
#
# 0.6146937608718872
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# Epochs 274
#
# 0.45470181107521057
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 275
#
# 0.5390452146530151
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# Epochs 276
#
# 0.49304962158203125
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# Epochs 277
#
# 0.5181256532669067
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 278
#
# 0.396880567073822
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# Epochs 279
#
# 0.5180618166923523
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# Epochs 280
#
# 0.4447248578071594
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# Epochs 281
#
# 0.47858840227127075
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 282
#
# 0.6551859378814697
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# Epochs 283
#
# 0.5427300930023193
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 284
#
# 0.41366344690322876
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# Epochs 285
#
# 0.4700823426246643
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 286
#
# 0.4935324192047119
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# Epochs 287
#
# 0.4683082103729248
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# Epochs 288
#
# 0.505202054977417
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# Epochs 289
#
# 0.5268158912658691
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# Epochs 290
#
# 0.5052782297134399
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# Epochs 291
#
# 0.5446865558624268
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# Epochs 292
#
# 0.49112215638160706
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# Epochs 293
#
# 0.47750231623649597
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 294
#
# 0.44351673126220703
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# Epochs 295
#
# 0.4866967797279358
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# Epochs 296
#
# 0.5962138772010803
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# Epochs 297
#
# 0.49189263582229614
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# Epochs 298
#
# 0.5433943271636963
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# Epochs 299
#
# 0.5221457481384277
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0


def test_nn_accuracy(N_ways,n_trials,loader):
    """Returns accuracy of one shot """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))

    n_right = 0
    
    for i in range(n_trials):
        pairs,targets = loader.make_oneshot_task(N_ways,"val")
        correct = nearest_neighbour_correct(pairs,targets)
        n_right += correct
    return 100.0 * n_right / n_trials


ways = np.arange(1, 60, 2)
resume =  False
val_accs, train_accs,nn_accs = [], [], []
trials = 450
for N in ways:
    val_accs.append(loader.test_oneshot(siamese_net, N,trials, "val", verbose=True))
    train_accs.append(loader.test_oneshot(siamese_net, N,trials, "train", verbose=True))
    nn_accs.append(test_nn_accuracy(N,trials, loader))
    
#plot the accuracy vs num categories for each
plt.plot(ways, val_accs, "m")
plt.plot(ways, train_accs, "y")
plt.plot(ways, nn_accs, "c")

plt.plot(ways,100.0/ways,"r")
plt.show()
# Out:
# Evaluating model on 450 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating model on 450 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 1 way one-shot learning tasks ...
# Evaluating model on 450 random 3 way one-shot learning tasks ...
# Got an average of 70.0% 3 way one-shot learning accuracy
# Evaluating model on 450 random 3 way one-shot learning tasks ...
# Got an average of 82.0% 3 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 3 way one-shot learning tasks ...
# Evaluating model on 450 random 5 way one-shot learning tasks ...
# Got an average of 60.0% 5 way one-shot learning accuracy
# Evaluating model on 450 random 5 way one-shot learning tasks ...
# Got an average of 66.44444444444444% 5 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 5 way one-shot learning tasks ...
# Evaluating model on 450 random 7 way one-shot learning tasks ...
# Got an average of 51.111111111111114% 7 way one-shot learning accuracy
# Evaluating model on 450 random 7 way one-shot learning tasks ...
# Got an average of 60.888888888888886% 7 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 7 way one-shot learning tasks ...
# Evaluating model on 450 random 9 way one-shot learning tasks ...
# Got an average of 44.44444444444444% 9 way one-shot learning accuracy
# Evaluating model on 450 random 9 way one-shot learning tasks ...
# Got an average of 52.22222222222222% 9 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 9 way one-shot learning tasks ...
# Evaluating model on 450 random 11 way one-shot learning tasks ...
# Got an average of 33.55555555555556% 11 way one-shot learning accuracy
# Evaluating model on 450 random 11 way one-shot learning tasks ...
# Got an average of 49.111111111111114% 11 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 11 way one-shot learning tasks ...
# Evaluating model on 450 random 13 way one-shot learning tasks ...
# Got an average of 37.111111111111114% 13 way one-shot learning accuracy
# Evaluating model on 450 random 13 way one-shot learning tasks ...
# Got an average of 47.333333333333336% 13 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 13 way one-shot learning tasks ...
# Evaluating model on 450 random 15 way one-shot learning tasks ...
# Got an average of 36.888888888888886% 15 way one-shot learning accuracy
# Evaluating model on 450 random 15 way one-shot learning tasks ...
# Got an average of 43.333333333333336% 15 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 15 way one-shot learning tasks ...
# Evaluating model on 450 random 17 way one-shot learning tasks ...
# Got an average of 31.555555555555557% 17 way one-shot learning accuracy
# Evaluating model on 450 random 17 way one-shot learning tasks ...
# Got an average of 41.333333333333336% 17 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 17 way one-shot learning tasks ...
# Evaluating model on 450 random 19 way one-shot learning tasks ...
# Got an average of 28.22222222222222% 19 way one-shot learning accuracy
# Evaluating model on 450 random 19 way one-shot learning tasks ...
# Got an average of 40.666666666666664% 19 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 19 way one-shot learning tasks ...
# Evaluating model on 450 random 21 way one-shot learning tasks ...
# Got an average of 26.88888888888889% 21 way one-shot learning accuracy
# Evaluating model on 450 random 21 way one-shot learning tasks ...
# Got an average of 33.333333333333336% 21 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 21 way one-shot learning tasks ...
# Evaluating model on 450 random 23 way one-shot learning tasks ...
# Got an average of 21.11111111111111% 23 way one-shot learning accuracy
# Evaluating model on 450 random 23 way one-shot learning tasks ...
# Got an average of 32.0% 23 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 23 way one-shot learning tasks ...
# Evaluating model on 450 random 25 way one-shot learning tasks ...
# Got an average of 26.88888888888889% 25 way one-shot learning accuracy
# Evaluating model on 450 random 25 way one-shot learning tasks ...
# Got an average of 35.111111111111114% 25 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 25 way one-shot learning tasks ...
# Evaluating model on 450 random 27 way one-shot learning tasks ...
# Got an average of 21.77777777777778% 27 way one-shot learning accuracy
# Evaluating model on 450 random 27 way one-shot learning tasks ...
# Got an average of 33.111111111111114% 27 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 27 way one-shot learning tasks ...
# Evaluating model on 450 random 29 way one-shot learning tasks ...
# Got an average of 21.333333333333332% 29 way one-shot learning accuracy
# Evaluating model on 450 random 29 way one-shot learning tasks ...
# Got an average of 30.0% 29 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 29 way one-shot learning tasks ...
# Evaluating model on 450 random 31 way one-shot learning tasks ...
# Got an average of 22.88888888888889% 31 way one-shot learning accuracy
# Evaluating model on 450 random 31 way one-shot learning tasks ...
# Got an average of 29.555555555555557% 31 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 31 way one-shot learning tasks ...
# Evaluating model on 450 random 33 way one-shot learning tasks ...
# Got an average of 19.77777777777778% 33 way one-shot learning accuracy
# Evaluating model on 450 random 33 way one-shot learning tasks ...
# Got an average of 28.88888888888889% 33 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 33 way one-shot learning tasks ...
# Evaluating model on 450 random 35 way one-shot learning tasks ...
# Got an average of 19.11111111111111% 35 way one-shot learning accuracy
# Evaluating model on 450 random 35 way one-shot learning tasks ...
# Got an average of 25.333333333333332% 35 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 35 way one-shot learning tasks ...
# Evaluating model on 450 random 37 way one-shot learning tasks ...
# Got an average of 20.666666666666668% 37 way one-shot learning accuracy
# Evaluating model on 450 random 37 way one-shot learning tasks ...
# Got an average of 29.555555555555557% 37 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 37 way one-shot learning tasks ...
# Evaluating model on 450 random 39 way one-shot learning tasks ...
# Got an average of 19.11111111111111% 39 way one-shot learning accuracy
# Evaluating model on 450 random 39 way one-shot learning tasks ...
# Got an average of 23.11111111111111% 39 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 39 way one-shot learning tasks ...
# Evaluating model on 450 random 41 way one-shot learning tasks ...
# Got an average of 16.22222222222222% 41 way one-shot learning accuracy
# Evaluating model on 450 random 41 way one-shot learning tasks ...
# Got an average of 23.555555555555557% 41 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 41 way one-shot learning tasks ...
# Evaluating model on 450 random 43 way one-shot learning tasks ...
# Got an average of 16.22222222222222% 43 way one-shot learning accuracy
# Evaluating model on 450 random 43 way one-shot learning tasks ...
# Got an average of 23.333333333333332% 43 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 43 way one-shot learning tasks ...
# Evaluating model on 450 random 45 way one-shot learning tasks ...
# Got an average of 14.88888888888889% 45 way one-shot learning accuracy
# Evaluating model on 450 random 45 way one-shot learning tasks ...
# Got an average of 22.444444444444443% 45 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 45 way one-shot learning tasks ...
# Evaluating model on 450 random 47 way one-shot learning tasks ...
# Got an average of 15.333333333333334% 47 way one-shot learning accuracy
# Evaluating model on 450 random 47 way one-shot learning tasks ...
# Got an average of 23.555555555555557% 47 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 47 way one-shot learning tasks ...
# Evaluating model on 450 random 49 way one-shot learning tasks ...
# Got an average of 13.555555555555555% 49 way one-shot learning accuracy
# Evaluating model on 450 random 49 way one-shot learning tasks ...
# Got an average of 19.333333333333332% 49 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 49 way one-shot learning tasks ...
# Evaluating model on 450 random 51 way one-shot learning tasks ...
# Got an average of 14.88888888888889% 51 way one-shot learning accuracy
# Evaluating model on 450 random 51 way one-shot learning tasks ...
# Got an average of 20.22222222222222% 51 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 51 way one-shot learning tasks ...
# Evaluating model on 450 random 53 way one-shot learning tasks ...
# Got an average of 13.11111111111111% 53 way one-shot learning accuracy
# Evaluating model on 450 random 53 way one-shot learning tasks ...
# Got an average of 20.444444444444443% 53 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 53 way one-shot learning tasks ...
# Evaluating model on 450 random 55 way one-shot learning tasks ...
# Got an average of 10.444444444444445% 55 way one-shot learning accuracy
# Evaluating model on 450 random 55 way one-shot learning tasks ...
# Got an average of 18.444444444444443% 55 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 55 way one-shot learning tasks ...
# Evaluating model on 450 random 57 way one-shot learning tasks ...
# Got an average of 14.0% 57 way one-shot learning accuracy
# Evaluating model on 450 random 57 way one-shot learning tasks ...
# Got an average of 18.444444444444443% 57 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 57 way one-shot learning tasks ...
# Evaluating model on 450 random 59 way one-shot learning tasks ...
# Got an average of 12.444444444444445% 59 way one-shot learning accuracy
# Evaluating model on 450 random 59 way one-shot learning tasks ...
# Got an average of 18.444444444444443% 59 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 59 way one-shot learning tasks ...

# %%
fig,ax = plt.subplots(1)
ax.plot(ways,val_accs,"m",label="Siamese(val set)")
ax.plot(ways,train_accs,"y",label="Siamese(train set)")
plt.plot(ways,nn_accs,label="Nearest neighbour")

ax.plot(ways,100.0/ways,"g",label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Omiglot One-Shot Learning Performance of a Siamese Network")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs,targets = loader.make_oneshot_task(20,"val")
plt.show()

print(inputs[0].shape)
plot_oneshot_task(inputs)
p=siamese_net.predict(inputs)
print(p)
# Out:
# (20, 105, 105, 1)
# [[0.15857488]
#  [0.01938825]
#  [0.17805783]
#  [0.52349895]
#  [0.02627356]
#  [0.00305657]
#  [0.07481046]
#  [0.01489519]
#  [0.62344015]
#  [0.17609599]
#  [0.28605238]
#  [0.07391959]
#  [0.48368505]
#  [0.02480368]
#  [0.4501279 ]
#  [0.45545384]
#  [0.00291577]
#  [0.42244217]
#  [0.51049536]
#  [0.00883461]]

# %%
a=test_nn_accuracy(3,500,loader)
print(a)
# Out:
# Evaluating nearest neighbour on 500 unique 3 way one-shot learning tasks ...
# 58.6
