# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
#%cd /content/drive/MyDrive/keras-oneshot
#!ls

# %%
from keras.layers import Input, Conv2D, Lambda, merge, Dense, Flatten,MaxPooling2D
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
import numpy.random as rng
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle
# %matplotlib inline
def W_init(shape,dtype=None):
    """Initialize weights as in paper"""
    return rng.normal(loc = 0.0, scale = 1e-2, size = shape)
#//TODO: figure out how to initialize layer biases in keras.
def b_init(shape,dtype=None):
    """Initialize bias as in paper"""
    return rng.normal(loc=0.5,scale=1e-2,size=shape)

input_shape = (105, 105, 1)
left_input = Input(input_shape)
right_input = Input(input_shape)
#build convnet to use in each siamese 'leg'
convnet = Sequential()
convnet.add(Conv2D(64,(10,10),activation='relu',input_shape=input_shape,
                   kernel_initializer=W_init,kernel_regularizer=l2(2e-4)))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(128,(7,7),activation='relu',
                   kernel_regularizer=l2(2e-4),kernel_initializer=W_init,bias_initializer=b_init))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(128,(4,4),activation='relu',kernel_initializer=W_init,kernel_regularizer=l2(2e-4),bias_initializer=b_init))
convnet.add(MaxPooling2D())
convnet.add(Conv2D(256,(4,4),activation='relu',kernel_initializer=W_init,kernel_regularizer=l2(2e-4),bias_initializer=b_init))
convnet.add(Flatten())
convnet.add(Dense(4096,activation="sigmoid",kernel_regularizer=l2(1e-3),kernel_initializer=W_init,bias_initializer=b_init))

#call the convnet Sequential model on each of the input tensors so params will be shared
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)
#layer to merge two encoded inputs with the l1 distance between them
L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
#call this layer on list of two input tensors.
L1_distance = L1_layer([encoded_l, encoded_r])
prediction = Dense(1,activation='sigmoid',bias_initializer=b_init)(L1_distance)
siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)

optimizer = Adam(0.00006)
#//TODO: get layerwise learning rates and momentum annealing scheme described in paperworking
siamese_net.compile(loss="binary_crossentropy",optimizer=optimizer)

siamese_net.count_params()
# Out:
# 38951745

# %% [markdown]
# ## Data
# The data is pickled as an N_classes x n_examples x width x height array, and there is an accompanyng dictionary to specify which indexes belong to which languages.

# %%
PATH = "/content/drive/MyDrive/keras-oneshot" #CHANGE THIS - path where the pickled data is stored

with open(os.path.join(PATH, "train.pickle"), "rb") as f:
    (X,c) = pickle.load(f)

with open(os.path.join(PATH, "val.pickle"), "rb") as f:
    (Xval,cval) = pickle.load(f)
    
print("training alphabets")
print(c.keys())
print("validation alphabets:")
print(cval.keys())
# Out:
# training alphabets
# dict_keys(['Alphabet_of_the_Magi', 'Bengali', 'Gujarati', 'Japanese_(katakana)', 'Mkhedruli_(Georgian)', 'Tagalog', 'Hebrew', 'Burmese_(Myanmar)', 'Early_Aramaic', 'Grantha', 'Armenian', 'Futurama', 'Tifinagh', 'Greek', 'Syriac_(Estrangelo)', 'Arcadian', 'Anglo-Saxon_Futhorc', 'Asomtavruli_(Georgian)', 'Malay_(Jawi_-_Arabic)', 'N_Ko', 'Sanskrit', 'Ojibwe_(Canadian_Aboriginal_Syllabics)', 'Braille', 'Korean', 'Cyrillic', 'Latin', 'Inuktitut_(Canadian_Aboriginal_Syllabics)', 'Blackfoot_(Canadian_Aboriginal_Syllabics)', 'Balinese', 'Japanese_(hiragana)'])
# validation alphabets:
# dict_keys(['Aurek-Besh', 'Tengwar', 'Tibetan', 'Malayalam', 'Ge_ez', 'Glagolitic', 'Atlantean', 'Keble', 'Manipuri', 'Avesta', 'Mongolian', 'Old_Church_Slavonic_(Cyrillic)', 'Kannada', 'Atemayar_Qelisayer', 'Sylheti', 'ULOG', 'Syriac_(Serto)', 'Gurmukhi', 'Oriya', 'Angelic'])

# %%
class Siamese_Loader:
    """For loading batches and testing tasks to a siamese net"""
    def __init__(self, path, data_subsets = ["train", "val"]):
        self.data = {}
        self.categories = {}
        self.info = {}
        
        for name in data_subsets:
            file_path = os.path.join(path, name + ".pickle")
            print("loading data from {}".format(file_path))
            with open(file_path,"rb") as f:
                (X,c) = pickle.load(f)
                self.data[name] = X
                self.categories[name] = c

    def get_batch(self,batch_size,s="train"):
        """Create batch of n pairs, half same class, half different class"""
        X=self.data[s]
        n_classes, n_examples, w, h = X.shape

        #randomly sample several classes to use in the batch
        categories = rng.choice(n_classes,size=(batch_size,),replace=False)
        #initialize 2 empty arrays for the input image batch
        pairs=[np.zeros((batch_size, h, w,1)) for i in range(2)]
        #initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
        targets=np.zeros((batch_size,))
        targets[batch_size//2:] = 1
        for i in range(batch_size):
            category = categories[i]
            idx_1 = rng.randint(0, n_examples)
            pairs[0][i,:,:,:] = X[category, idx_1].reshape(w, h, 1)
            idx_2 = rng.randint(0, n_examples)
            #pick images of same class for 1st half, different for 2nd
            if i >= batch_size // 2:
                category_2 = category  
            else: 
                #add a random number to the category modulo n classes to ensure 2nd image has
                # ..different category
                category_2 = (category + rng.randint(1,n_classes)) % n_classes
            pairs[1][i,:,:,:] = X[category_2,idx_2].reshape(w, h,1)
        return pairs, targets
    
    def generate(self, batch_size, s="train"):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.get_batch(batch_size,s)
            yield (pairs, targets)    

    def make_oneshot_task(self,N,s="val",language=None):
        """Create pairs of test image, support set for testing N way one-shot learning. """
        X=self.data[s]
        n_classes, n_examples, w, h = X.shape
        indices = rng.randint(0,n_examples,size=(N,))
        if language is not None:
            low, high = self.categories[s][language]
            if N > high - low:
                raise ValueError("This language ({}) has less than {} letters".format(language, N))
            categories = rng.choice(range(low,high),size=(N,),replace=False)
            
        else:#if no language specified just pick a bunch of random letters
            categories = rng.choice(range(n_classes),size=(N,),replace=False)            
        true_category = categories[0]
        ex1, ex2 = rng.choice(n_examples,replace=False,size=(2,))
        test_image = np.asarray([X[true_category,ex1,:,:]]*N).reshape(N, w, h,1)
        support_set = X[categories,indices,:,:]
        support_set[0,:,:] = X[true_category,ex2]
        support_set = support_set.reshape(N, w, h,1)
        targets = np.zeros((N,))
        targets[0] = 1
        targets, test_image, support_set = shuffle(targets, test_image, support_set)
        pairs = [test_image,support_set]

        return pairs, targets
    
    def test_oneshot(self,model,N,k,s="val",verbose=0):
        """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
        n_correct = 0
        if verbose:
            print("Evaluating model on {} random {} way one-shot learning tasks ...".format(k,N))
        for i in range(k):
            inputs, targets = self.make_oneshot_task(N,s)
            probs = model.predict(inputs)
            if np.argmax(probs) == np.argmax(targets):
                n_correct+=1
        percent_correct = (100.0*n_correct / k)
        if verbose:
            print("Got an average of {}% {} way one-shot learning accuracy".format(percent_correct,N))
        return percent_correct
    
    def train(self, model, epochs, verbosity):
        model.fit_generator(self.generate(batch_size),
                            
                             )
    
    
#Instantiate the class
loader = Siamese_Loader(PATH)
# Out:
# loading data from /content/drive/MyDrive/keras-oneshot/train.pickle
# loading data from /content/drive/MyDrive/keras-oneshot/val.pickle

# %%
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    nc,h,w,_ = X.shape
    X = X.reshape(nc,h,w)
    n = np.ceil(np.sqrt(nc)).astype("int8")
    img = np.zeros((n*w,n*h))
    x = 0
    y = 0
    for example in range(nc):
        img[x*w:(x+1)*w,y*h:(y+1)*h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img


def plot_oneshot_task(pairs):
    """Takes a one-shot task given to a siamese net and  """
    fig,(ax1,ax2) = plt.subplots(2)
    ax1.matshow(pairs[0][0].reshape(105,105),cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img,cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()
#example of a one-shot learning task
pairs, targets = loader.make_oneshot_task(20,"train","Japanese_(katakana)")
plot_oneshot_task(pairs)

# %%
#Training loop
print("!")
evaluate_every = 1 # interval for evaluating on one-shot tasks
loss_every=50 # interval for printing loss (iterations)
batch_size = 32
n_iter = 90000
N_way = 20 # how many classes for testing one-shot tasks>
n_val = 250 #how mahy one-shot tasks to validate on?
best = -1
weights_path = os.path.join(PATH, "weights")
print("training")
for i in range(1, n_iter):
    (inputs,targets)=loader.get_batch(batch_size)
    loss=siamese_net.train_on_batch(inputs,targets)
    print(loss)
    if i % evaluate_every == 0:
        print("evaluating")
        val_acc = loader.test_oneshot(siamese_net,N_way,n_val,verbose=True)
        if val_acc >= best:
            print("saving")
            siamese_net.save(weights_path)
            best=val_acc

    if i % loss_every == 0:
        print("iteration {}, training loss: {:.2f},".format(i,loss))
# Out:
# !
# training
# 4.518796443939209
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 4.47368049621582
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 4.428410053253174
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 4.417471885681152
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 4.4156622886657715
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.6% 20 way one-shot learning accuracy
# 4.380184650421143
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 4.3622026443481445
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 4.329371452331543
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# 4.334597110748291
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.4% 20 way one-shot learning accuracy
# 4.3023362159729
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.0% 20 way one-shot learning accuracy
# 4.269940376281738
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 4.237936973571777
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 33.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 4.24747896194458
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.4% 20 way one-shot learning accuracy
# 4.176201820373535
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.0% 20 way one-shot learning accuracy
# 4.138991355895996
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 4.15470027923584
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 4.1577301025390625
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 4.0746660232543945
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 4.089561462402344
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# 4.089140892028809
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 4.009585857391357
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# 4.0148749351501465
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# 3.9500951766967773
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# 3.9202094078063965
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# 3.93776535987854
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 3.987823247909546
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 3.972938299179077
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# 3.9318172931671143
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 3.8870797157287598
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.0% 20 way one-shot learning accuracy
# 3.9673094749450684
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# 3.8337323665618896
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# 3.9230520725250244
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 3.889862060546875
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.4% 20 way one-shot learning accuracy
# 3.9935295581817627
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# 3.808971405029297
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# 3.7463202476501465
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 3.737471580505371
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# 3.8825464248657227
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 3.698563575744629
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# 3.8972678184509277
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# 3.7107415199279785
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# 3.7149293422698975
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# 3.7038776874542236
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# 3.6944990158081055
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# 3.631953716278076
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 3.547278881072998
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 3.6660265922546387
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 3.676053047180176
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 3.591559410095215
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# 3.5282387733459473
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# iteration 50, training loss: 3.53,
# 3.586398124694824
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 3.5992074012756348
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 3.5630688667297363
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# 3.470125436782837
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# 3.586768388748169
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 3.5487496852874756
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 3.5218489170074463
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.2% 20 way one-shot learning accuracy
# 3.4524807929992676
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# 3.4451606273651123
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# 3.3906195163726807
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# 3.4536352157592773
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.8% 20 way one-shot learning accuracy
# 3.4010586738586426
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# 3.3996827602386475
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.6% 20 way one-shot learning accuracy
# 3.400001049041748
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# 3.6063239574432373
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# 3.377328872680664
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# 3.3901658058166504
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# 3.4347083568573
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 14.4% 20 way one-shot learning accuracy
# 3.420698642730713
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.0% 20 way one-shot learning accuracy
# 3.262571334838867
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 15.6% 20 way one-shot learning accuracy
# 3.2153594493865967
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 3.476592540740967
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 3.2669990062713623
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.2% 20 way one-shot learning accuracy
# 3.3182055950164795
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# 3.331153154373169
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# 3.323694944381714
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# 3.2374191284179688
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 3.2951579093933105
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 3.245147705078125
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# 3.2141075134277344
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 16.8% 20 way one-shot learning accuracy
# 3.4772567749023438
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# 3.1885688304901123
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# 3.391587495803833
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# 3.1789186000823975
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 3.2354183197021484
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# 3.2591915130615234
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# 3.2035717964172363
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# 3.1818225383758545
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 3.249267578125
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 3.0875911712646484
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 3.14096736907959
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# 3.294267416000366
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 3.1859378814697266
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# 3.1816933155059814
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.2% 20 way one-shot learning accuracy
# 3.149357795715332
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.8% 20 way one-shot learning accuracy
# 3.1499557495117188
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# 3.107311487197876
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# 3.273094654083252
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 2.9816951751708984
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 3.062051773071289
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# iteration 100, training loss: 3.06,
# 3.1083626747131348
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 2.9863219261169434
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# 2.9893670082092285
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 3.028904676437378
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# 3.1042308807373047
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# 3.0232582092285156
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# 3.078856945037842
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 17.2% 20 way one-shot learning accuracy
# 3.0336501598358154
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 18.4% 20 way one-shot learning accuracy
# 3.02470064163208
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# 2.9423327445983887
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# 3.0418472290039062
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.962498664855957
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# 2.941779375076294
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# 3.0425734519958496
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 2.918882369995117
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# 2.956749439239502
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 3.0153260231018066
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# 2.9052038192749023
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.0% 20 way one-shot learning accuracy
# 2.8816869258880615
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# 2.9216103553771973
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# 3.0024971961975098
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 3.024630308151245
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.0% 20 way one-shot learning accuracy
# 2.820338010787964
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.2% 20 way one-shot learning accuracy
# 2.7520651817321777
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.8018829822540283
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 2.8444442749023438
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.8037824630737305
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# 2.772409439086914
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.800243854522705
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.7956502437591553
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.7387967109680176
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 2.8348464965820312
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.2% 20 way one-shot learning accuracy
# 2.745117664337158
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.903853178024292
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.8934032917022705
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 2.6927950382232666
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.798994779586792
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# 2.8056654930114746
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# 2.809284210205078
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 2.728205442428589
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.6% 20 way one-shot learning accuracy
# 2.821113348007202
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.7905354499816895
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.7349789142608643
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# 2.653118848800659
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.7905125617980957
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.658459424972534
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.763932466506958
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# 2.755845785140991
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.7073333263397217
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.7138962745666504
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# iteration 150, training loss: 2.71,
# 2.7886340618133545
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# 2.665363073348999
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.8% 20 way one-shot learning accuracy
# 2.6020426750183105
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 2.6371514797210693
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 2.658390760421753
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.7399349212646484
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# 2.6567771434783936
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.7519373893737793
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 2.563270092010498
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.717639207839966
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.5318055152893066
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.7152044773101807
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.0% 20 way one-shot learning accuracy
# 2.5330617427825928
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# 2.6276907920837402
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# 2.6900177001953125
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.5033817291259766
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# 2.4452340602874756
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 2.454577684402466
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# 2.6770763397216797
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.4% 20 way one-shot learning accuracy
# 2.5373663902282715
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.8% 20 way one-shot learning accuracy
# 2.7307848930358887
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# 2.445544481277466
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.6474382877349854
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.675307273864746
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.4% 20 way one-shot learning accuracy
# 2.517454147338867
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# 2.4837398529052734
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.484243392944336
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# 2.439579486846924
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.2% 20 way one-shot learning accuracy
# 2.429757595062256
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.4645845890045166
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.3936140537261963
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.6% 20 way one-shot learning accuracy
# 2.3751344680786133
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.5057694911956787
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.511688232421875
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.500453472137451
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.552978038787842
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 2.579050064086914
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.4% 20 way one-shot learning accuracy
# 2.3602328300476074
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# 2.4502058029174805
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 2.4677112102508545
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.420186996459961
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# 2.485272169113159
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.2% 20 way one-shot learning accuracy
# 2.3647615909576416
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.2978997230529785
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.8% 20 way one-shot learning accuracy
# 2.37307071685791
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# 2.264235734939575
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# 2.4090960025787354
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# 2.4443514347076416
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.350774049758911
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# 2.4912290573120117
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 34.4% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# iteration 200, training loss: 2.49,
# 2.3215765953063965
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# 2.3623478412628174
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 34.4% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 2.2533957958221436
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 34.0% 20 way one-shot learning accuracy
# 2.349599838256836
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.2% 20 way one-shot learning accuracy
# 2.413250207901001
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.6003103256225586
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.2% 20 way one-shot learning accuracy
# 2.416922092437744
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 2.2593960762023926
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.49223256111145
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# 2.355269193649292
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# 2.4133546352386475
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 2.3347694873809814
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.394458770751953
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.3115200996398926
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.0% 20 way one-shot learning accuracy
# 2.1953835487365723
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 2.281909704208374
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.3360626697540283
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.270266532897949
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.3303024768829346
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# 2.2871522903442383
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.281219959259033
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# 2.3629097938537598
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.1450271606445312
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# 2.3654699325561523
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.284093141555786
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 19.6% 20 way one-shot learning accuracy
# 2.2302019596099854
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.165147542953491
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 20.8% 20 way one-shot learning accuracy
# 2.2157211303710938
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.6% 20 way one-shot learning accuracy
# 2.253032684326172
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# 2.247584819793701
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# 2.246079921722412
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.323852777481079
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# 2.3811166286468506
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.8% 20 way one-shot learning accuracy
# 2.295440435409546
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.8% 20 way one-shot learning accuracy
# 2.288923978805542
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.289494276046753
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.2% 20 way one-shot learning accuracy
# 2.1186704635620117
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# 2.158115863800049
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# 2.1698007583618164
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# 2.2009644508361816
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 2.3389878273010254
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.2688279151916504
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 33.6% 20 way one-shot learning accuracy
# 2.215341567993164
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 2.16855525970459
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.3685951232910156
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 2.3794283866882324
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.0828049182891846
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.6% 20 way one-shot learning accuracy
# 2.284605026245117
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.8% 20 way one-shot learning accuracy
# 2.1546051502227783
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.218338966369629
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# iteration 250, training loss: 2.22,
# 2.182652235031128
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.264537811279297
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 37.2% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 2.1698875427246094
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.8% 20 way one-shot learning accuracy
# 2.0800986289978027
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 1.9670276641845703
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.6% 20 way one-shot learning accuracy
# 2.200100898742676
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.0428218841552734
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.3054890632629395
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.0% 20 way one-shot learning accuracy
# 2.1589648723602295
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# 2.2330729961395264
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# 2.333042621612549
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 22.4% 20 way one-shot learning accuracy
# 2.1876606941223145
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 21.2% 20 way one-shot learning accuracy
# 2.205199718475342
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.6% 20 way one-shot learning accuracy
# 2.150165557861328
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.6% 20 way one-shot learning accuracy
# 1.9832251071929932
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 25.2% 20 way one-shot learning accuracy
# 2.0737838745117188
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.0% 20 way one-shot learning accuracy
# 2.2040553092956543
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.1881561279296875
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.1093223094940186
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 2.0522494316101074
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# 2.1488308906555176
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.2% 20 way one-shot learning accuracy
# 2.007474899291992
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.4% 20 way one-shot learning accuracy
# 2.0006401538848877
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.2% 20 way one-shot learning accuracy
# 2.055131435394287
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 34.0% 20 way one-shot learning accuracy
# 2.2021985054016113
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.8% 20 way one-shot learning accuracy
# 2.1465518474578857
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.8% 20 way one-shot learning accuracy
# 2.0932817459106445
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.0% 20 way one-shot learning accuracy
# 1.9571090936660767
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.2% 20 way one-shot learning accuracy
# 2.032503843307495
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 36.8% 20 way one-shot learning accuracy
# 2.1229124069213867
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.4% 20 way one-shot learning accuracy
# 2.053715229034424
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 34.8% 20 way one-shot learning accuracy
# 1.9753918647766113
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 34.8% 20 way one-shot learning accuracy
# 2.0658347606658936
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 2.16072678565979
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 2.101874351501465
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 38.8% 20 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/keras-oneshot/weights/assets
# 2.0867416858673096
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 33.6% 20 way one-shot learning accuracy
# 2.118910312652588
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.8% 20 way one-shot learning accuracy
# 2.1492133140563965
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.2% 20 way one-shot learning accuracy
# 2.0524508953094482
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.8% 20 way one-shot learning accuracy
# 2.072206735610962
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# 1.9852603673934937
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.6% 20 way one-shot learning accuracy
# 1.9910519123077393
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 34.4% 20 way one-shot learning accuracy
# 1.9618523120880127
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 27.2% 20 way one-shot learning accuracy
# 2.066819667816162
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# 2.0028131008148193
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.8% 20 way one-shot learning accuracy
# 2.0185186862945557
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 30.4% 20 way one-shot learning accuracy
# 1.9433561563491821
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.4% 20 way one-shot learning accuracy
# 2.0372848510742188
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 26.8% 20 way one-shot learning accuracy
# 1.9044017791748047
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 32.0% 20 way one-shot learning accuracy
# 1.9223573207855225
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.6% 20 way one-shot learning accuracy
# iteration 300, training loss: 1.92,
# 1.9867409467697144
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 29.6% 20 way one-shot learning accuracy
# 1.8701421022415161
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 31.2% 20 way one-shot learning accuracy
# 1.805693507194519
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 28.0% 20 way one-shot learning accuracy
# 1.9410357475280762
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 23.6% 20 way one-shot learning accuracy
# 1.983098030090332
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 24.4% 20 way one-shot learning accuracy
# 2.0163655281066895
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 1.0729398727416992
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 62.0% 20 way one-shot learning accuracy
# 1.0967398881912231
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.8% 20 way one-shot learning accuracy
# 0.9904398918151855
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# 1.2713253498077393
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.8% 20 way one-shot learning accuracy
# 1.096855640411377
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 60.4% 20 way one-shot learning accuracy
# 1.0492231845855713
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# 0.9303812384605408
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.4% 20 way one-shot learning accuracy
# 0.9725936651229858
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 55.6% 20 way one-shot learning accuracy
# 0.9777281284332275
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 59.6% 20 way one-shot learning accuracy
# 1.0847210884094238
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.4% 20 way one-shot learning accuracy
# 1.166658639907837
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 49.2% 20 way one-shot learning accuracy
# 1.059971809387207
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.4% 20 way one-shot learning accuracy
# 1.0410706996917725
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 53.2% 20 way one-shot learning accuracy
# 0.9686880111694336
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.4% 20 way one-shot learning accuracy
# 1.0713725090026855
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.8% 20 way one-shot learning accuracy
# 1.0191837549209595
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 1.1035093069076538
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 49.2% 20 way one-shot learning accuracy
# 0.9995741248130798
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 59.2% 20 way one-shot learning accuracy
# 1.2072292566299438
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 56.4% 20 way one-shot learning accuracy
# 0.9510688185691833
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 57.2% 20 way one-shot learning accuracy
# 1.1299422979354858
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 1.1789250373840332
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 56.4% 20 way one-shot learning accuracy
# 1.0795278549194336
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 51.6% 20 way one-shot learning accuracy
# 0.9893584251403809
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 55.6% 20 way one-shot learning accuracy
# 1.0738446712493896
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.8% 20 way one-shot learning accuracy
# 1.1312425136566162
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.8% 20 way one-shot learning accuracy
# 1.1582831144332886
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.8% 20 way one-shot learning accuracy
# iteration 950, training loss: 1.16,
# 1.1954926252365112
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 1.148142695426941
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 53.6% 20 way one-shot learning accuracy
# 1.1038568019866943
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 55.6% 20 way one-shot learning accuracy
# 1.071295976638794
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 49.6% 20 way one-shot learning accuracy
# 1.0756797790527344
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 51.6% 20 way one-shot learning accuracy
# 1.0793507099151611
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 1.0432085990905762
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.4% 20 way one-shot learning accuracy
# 0.9783530831336975
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.8% 20 way one-shot learning accuracy
# 1.1265549659729004
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 57.2% 20 way one-shot learning accuracy
# 0.9734841585159302
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.8% 20 way one-shot learning accuracy
# 1.0256191492080688
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.4% 20 way one-shot learning accuracy
# 1.1058381795883179
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.4% 20 way one-shot learning accuracy
# 1.1392536163330078
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 60.4% 20 way one-shot learning accuracy
# 0.9142166376113892
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.4% 20 way one-shot learning accuracy
# 1.100408673286438
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 60.0% 20 way one-shot learning accuracy
# 0.9984548687934875
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 59.2% 20 way one-shot learning accuracy
# 0.9994356036186218
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 59.2% 20 way one-shot learning accuracy
# 1.0570738315582275
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 57.6% 20 way one-shot learning accuracy
# 1.0127708911895752
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.0% 20 way one-shot learning accuracy
# 1.0777312517166138
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 1.1003532409667969
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 55.6% 20 way one-shot learning accuracy
# 1.0675724744796753
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 50.0% 20 way one-shot learning accuracy
# 1.0179529190063477
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 56.0% 20 way one-shot learning accuracy
# 1.0103634595870972
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# 0.9163007736206055
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 55.6% 20 way one-shot learning accuracy
# 1.008897066116333
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.4% 20 way one-shot learning accuracy
# 1.2403991222381592
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 57.6% 20 way one-shot learning accuracy
# 1.0267326831817627
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 57.2% 20 way one-shot learning accuracy
# 0.9593320488929749
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 55.6% 20 way one-shot learning accuracy
# 1.010500192642212
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.8% 20 way one-shot learning accuracy
# 0.9408431649208069
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 62.8% 20 way one-shot learning accuracy
# 1.0897659063339233
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.8% 20 way one-shot learning accuracy
# 1.1009187698364258
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.4% 20 way one-shot learning accuracy
# 1.0342833995819092
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 50.4% 20 way one-shot learning accuracy
# 0.9519305229187012
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 56.8% 20 way one-shot learning accuracy
# 1.0714409351348877
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.4% 20 way one-shot learning accuracy
# 0.9626903533935547
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 53.6% 20 way one-shot learning accuracy
# 0.9713550209999084
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 54.0% 20 way one-shot learning accuracy
# 1.0177613496780396
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.0% 20 way one-shot learning accuracy
# 0.9027091264724731
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 50.4% 20 way one-shot learning accuracy
# 0.9911104440689087
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 53.6% 20 way one-shot learning accuracy
# 1.0696077346801758
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.8% 20 way one-shot learning accuracy
# 1.0440592765808105
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 48.0% 20 way one-shot learning accuracy
# 0.980262279510498
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 57.6% 20 way one-shot learning accuracy
# 0.9151319861412048
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 48.4% 20 way one-shot learning accuracy
# 0.989785373210907
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 57.6% 20 way one-shot learning accuracy
# 0.9172295928001404
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 60.8% 20 way one-shot learning accuracy
# 0.9494049549102783
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 49.6% 20 way one-shot learning accuracy
# 0.9297301769256592
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 55.6% 20 way one-shot learning accuracy
# 1.0650734901428223
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 58.8% 20 way one-shot learning accuracy
# iteration 1000, training loss: 1.07,
# 0.9384169578552246
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.4% 20 way one-shot learning accuracy
# 1.1835331916809082
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 52.0% 20 way one-shot learning accuracy
# 1.006532907485962
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 59.2% 20 way one-shot learning accuracy
# 1.0936299562454224
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 63.2% 20 way one-shot learning accuracy
# 1.2031062841415405
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# Got an average of 53.2% 20 way one-shot learning accuracy
# 0.9324809312820435
# evaluating
# Evaluating model on 250 random 20 way one-shot learning tasks ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-23683fb8fd43> in <module>()
#      17     if i % evaluate_every == 0:
#      18         print("evaluating")
# ---> 19         val_acc = loader.test_oneshot(siamese_net,N_way,n_val,verbose=True)
#      20         if val_acc >= best:
#      21             print("saving")
#
# <ipython-input-10-72e05c4b4c66> in test_oneshot(self, model, N, k, s, verbose)
#      80         for i in range(k):
#      81             inputs, targets = self.make_oneshot_task(N,s)
# ---> 82             probs = model.predict(inputs)
#      83             if np.argmax(probs) == np.argmax(targets):
#      84                 n_correct+=1
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1645       callbacks.on_predict_end()
#    1646     all_outputs = nest.map_structure_up_to(batch_outputs, concat, outputs)
# -> 1647     return tf_utils.to_numpy_or_python_type(all_outputs)
#    1648
#    1649   def reset_metrics(self):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/tf_utils.py in to_numpy_or_python_type(tensors)
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#     513
# --> 514   return nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     515
#     516
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     657
#     658   return pack_sequence_as(
# --> 659       structure[0], [func(*x) for x in entries],
#     660       expand_composites=expand_composites)
#     661
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     508   def _to_single_numpy_or_python_type(t):
#     509     if isinstance(t, ops.Tensor):
# --> 510       x = t.numpy()
#     511       return x.item() if np.ndim(x) == 0 else x
#     512     return t  # Don't turn ragged or sparse tensors to NumPy.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1069     """
#    1070     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1071     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1072     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1073
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1035   def _numpy(self):
#    1036     try:
# -> 1037       return self._numpy_internal()
#    1038     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1039       six.raise_from(core._status_to_exception(e.code, e.message), None)  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0


def test_nn_accuracy(N_ways,n_trials,loader):
    """Returns accuracy of one shot """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))

    n_right = 0
    
    for i in range(n_trials):
        pairs,targets = loader.make_oneshot_task(N_ways,"val")
        correct = nearest_neighbour_correct(pairs,targets)
        n_right += correct
    return 100.0 * n_right / n_trials


ways = np.arange(1, 60, 2)
resume =  False
val_accs, train_accs,nn_accs = [], [], []
trials = 450
for N in ways:
    val_accs.append(loader.test_oneshot(siamese_net, N,trials, "val", verbose=True))
    train_accs.append(loader.test_oneshot(siamese_net, N,trials, "train", verbose=True))
    nn_accs.append(test_nn_accuracy(N,trials, loader))
    
#plot the accuracy vs num categories for each
plt.plot(ways, val_accs, "m")
plt.plot(ways, train_accs, "y")
plt.plot(ways, nn_accs, "c")

plt.plot(ways,100.0/ways,"r")
plt.show()
# Out:
# Evaluating model on 450 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating model on 450 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 1 way one-shot learning tasks ...
# Evaluating model on 450 random 3 way one-shot learning tasks ...
# Got an average of 86.88888888888889% 3 way one-shot learning accuracy
# Evaluating model on 450 random 3 way one-shot learning tasks ...
# Got an average of 93.77777777777777% 3 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 3 way one-shot learning tasks ...
# Evaluating model on 450 random 5 way one-shot learning tasks ...
# Got an average of 81.33333333333333% 5 way one-shot learning accuracy
# Evaluating model on 450 random 5 way one-shot learning tasks ...
# Got an average of 87.77777777777777% 5 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 5 way one-shot learning tasks ...
# Evaluating model on 450 random 7 way one-shot learning tasks ...
# Got an average of 76.22222222222223% 7 way one-shot learning accuracy
# Evaluating model on 450 random 7 way one-shot learning tasks ...
# Got an average of 86.88888888888889% 7 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 7 way one-shot learning tasks ...
# Evaluating model on 450 random 9 way one-shot learning tasks ...
# Got an average of 70.0% 9 way one-shot learning accuracy
# Evaluating model on 450 random 9 way one-shot learning tasks ...
# Got an average of 83.77777777777777% 9 way one-shot learning accuracy
# Evaluating nearest neighbour on 450 unique 9 way one-shot learning tasks ...
# Evaluating model on 450 random 11 way one-shot learning tasks ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-1d40abfc02b0> in <module>()
#      28 trials = 450
#      29 for N in ways:
# ---> 30     val_accs.append(loader.test_oneshot(siamese_net, N,trials, "val", verbose=True))
#      31     train_accs.append(loader.test_oneshot(siamese_net, N,trials, "train", verbose=True))
#      32     nn_accs.append(test_nn_accuracy(N,trials, loader))
#
# <ipython-input-10-72e05c4b4c66> in test_oneshot(self, model, N, k, s, verbose)
#      80         for i in range(k):
#      81             inputs, targets = self.make_oneshot_task(N,s)
# ---> 82             probs = model.predict(inputs)
#      83             if np.argmax(probs) == np.argmax(targets):
#      84                 n_correct+=1
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1627           for step in data_handler.steps():
#    1628             callbacks.on_predict_batch_begin(step)
# -> 1629             tmp_batch_outputs = self.predict_function(iterator)
#    1630             if data_handler.should_sync:
#    1631               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
fig,ax = plt.subplots(1)
ax.plot(ways,val_accs,"m",label="Siamese(val set)")
ax.plot(ways,train_accs,"y",label="Siamese(train set)")
plt.plot(ways,nn_accs,label="Nearest neighbour")

ax.plot(ways,100.0/ways,"g",label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Omiglot One-Shot Learning Performance of a Siamese Network")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs,targets = loader.make_oneshot_task(20,"val")
plt.show()

print(inputs[0].shape)
plot_oneshot_task(inputs)
p=siamese_net.predict(inputs)
print(p)

# %%
a=test_nn_accuracy(3,500,loader)
print(a)
